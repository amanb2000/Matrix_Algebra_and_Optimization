# %% [markdown]
# # Portfolio Design
# _ECE367 PS05 Problem 5.7 -- Aman Bhargava_
#
# ## Problem Setup
#
# - $p\in \mathbb{R}^n$; $\sum_{i=1}^n p_i = 1$. $p_i \geq 0$ $\forall$ $i\in[n]$
# - Each stock has expected returns in $\bar{x}\in\mathbb{R}^n$.
# - $\mathbb{E}[(\bar{x}_i-x_i)^2] = \Sigma_{ii}$
# - $\mathbb{E}[(x-x_i)(x-x_j)] \to \Sigma_{ij}$
#
# ------------------------------
#
# - Variance of investment $p$ is $p^T\Sigma p$. We wish to minimize variance of investment with minimum expected return $r_\min$.

# %%
# IMPORT BOX #

using LinearAlgebra
using Plots
using JuMP, Ipopt
import GLPK

using Convex, SCS
# Out:
# ┌ Info: Precompiling Convex [f65535da-76fb-5f13-bab9-19810c17039a]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling SCS [c946c3f1-0d1f-5ce8-9dea-7daa1f7e2d13]
# └ @ Base loading.jl:1278

# %%
x̄ = [1.1; 1.25; 1.25; 1.05]

Σ = [0.2 -0.2 -0.12 0.02;
     -0.2 1.4 0.02 0; 
     -0.12 0.2 1 -0.4; 
     0.02 0 -0.4 0.2]

Σ+=transpose(Σ)
Σ*=0.5
# Out:
# 4×4 Array{Float64,2}:
#   0.2   -0.2   -0.12   0.02
#  -0.2    1.4    0.11   0.0
#  -0.12   0.11   1.0   -0.4
#   0.02   0.0   -0.4    0.2

# %%
# Let us first make the Convex.jl module available

function get_var(r)
    # Generate random problem data
    m = 4;  n = 4

    # Create a (column vector) variable of size n x 1.
    x = Variable(4)
    r_imposed = r

    # The problem is to minimize ||Ax - b||^2 subject to x >= 0
    # This can be done by: minimize(objective, constraints)
    problem = minimize(sum(quadform(x, Σ)), [sum(x) == 1, x >= 0, sum(x̄.*x) >= r_imposed])

    # Solve the problem by calling solve!
    solve!(problem, SCS.Optimizer)

    # Check the status of the problem
#     problem.status # :Optimal, :Infeasible, :Unbounded etc.

    # Get the optimal value
    return problem.optval
end
# Out:
# get_var (generic function with 1 method)

# %%
rs = (1:50)/200 .+1
risk = zeros(50)

for i = 1:50
    risk[i] = get_var(rs[i])
end
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 4.70e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.63e+19  1.33e+19  1.00e+00 -3.33e+19  6.13e+18  3.70e+19  4.29e-05
#     40| 4.00e-11  4.10e-11  1.03e-10  1.28e-02  1.28e-02  7.97e-17  2.80e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.82e-04s
# 	Lin-sys: avg # CG iterations: 1.88, avg solve time: 7.82e-07s
# 	Cones: avg projection time: 9.33e-08s
# 	Acceleration: avg step time: 4.23e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 8.9512e-17, dist(y, K*) = 2.7756e-17, s'y/|s||y| = 4.8186e-17
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 4.0047e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 4.0978e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.0322e-10
# ----------------------------------------------------------------------------
# c'x = 0.0128, -b'y = 0.0128
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 3.61e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.63e+19  1.33e+19  1.00e+00 -3.34e+19  6.15e+18  3.70e+19  1.84e-05
#     40| 7.76e-11  7.74e-11  1.28e-10  1.28e-02  1.28e-02  3.59e-17  2.06e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.07e-04s
# 	Lin-sys: avg # CG iterations: 1.85, avg solve time: 6.02e-07s
# 	Cones: avg projection time: 8.45e-08s
# 	Acceleration: avg step time: 3.35e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.1102e-16, dist(y, K*) = 1.1102e-16, s'y/|s||y| =
-16, dist(y, K*) = 0.0000e+00, s'y/|s||y| = -4.1991e-17
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.8716e-06
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 3.6526e-06
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 6.8576e-06
# ----------------------------------------------------------------------------
# c'x = 0.0130, -b'y = 0.0130
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 2.82e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.64e+19  1.36e+19  1.00e+00 -3.45e+19  6.67e+18  3.74e+19  1.66e-05
#     40| 6.60e-10  8.63e-10  1.39e-10  1.44e-02  1.44e-02  6.24e-17  2.61e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.62e-04s
# 	Lin-sys: avg # CG iterations: 1.98, avg solve time: 1.10e-06s
# 	Cones: avg projection time: 8.33e-08s
# 	Acceleration: avg step time: 4.01e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 2.0244e-16, dist(y, K*) = 1.1102e-16, s'y/|s||y| = -8.9200e-17
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 6.6029e-10
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 8.6285e-10
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.3920e-10
# ----------------------------------------------------------------------------
# c'x = 0.0144, -b'y = 0.0144
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 2.88e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.64e+19  1.36e+19  1.00e+00 -3.45e+19  6.70e+18  3.74e+19  1.69e-05
#     40| 3.23e-09  7.20e-09  5.40e-09  1.73e-02  1.73e-02  2.20e-16  1.96e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 1.97e-04s
# 	Lin-sys: avg # CG iterations: 1.98, avg solve time: 6.06e-07s
# 	Cones: avg projection time: 6.89e-08s
# 	Acceleration: avg step time: 3.18e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 7.8014e-17, dist(y, K*) = 0.0000e+00, s'y/|s||y| = -2.6855e-17
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 3.2262e-09
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 7.2034e-09
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 5.4041e-09
# ----------------------------------------------------------------------------
# c'x = 0.0173, -b'y = 0.0173
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 3.36e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.64e+19  1.36e+19  1.00e+00 -3.46e+19  6.73e+18  3.74e+19  1.69e-05
#     40| 2.58e-06  5.56e-06  4.10e-06  2.17e-02  2.17e-02  1.51e-16  2.01e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.02e-04s
# 	Lin-sys: avg # CG iterations: 2.66, avg solve time: 7.18e-07s
# 	Cones: avg projection time: 7.68e-08s
# 	Acceleration: avg step time: 3.18e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.9058e-16, dist(y, K*) = 1.1102e-16, s'y/|s||y| = 1.0717e-16
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 2.5770e-06
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 5.5620e-06
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 4.0979e-06
# ----------------------------------------------------------------------------
# c'x = 0.0217, -b'y = 0.0217
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 2.92e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.64e+19  1.36e+19  1.00e+00 -3.46e+19  6.76e+18  3.74e+19  1.69e-05
#    100| 3.30e-04  4.32e-04  9.62e-04  2.65e-02  2.76e-02  1.30e-16  4.74e-04
#    120| 3.16e-09  5.07e-09  6.05e-09  2.75e-02  2.75e-02  9.20e-17  5.61e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 5.61e-04s
# 	Lin-sys: avg # CG iterations: 2.98, avg solve time: 7.09e-07s
# 	Cones: avg projection time: 6.92e-08s
# 	Acceleration: avg step time: 3.17e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 2.2204e-16, dist(y, K*) = 5.5511e-17, s'y/|s||y| = -4.7684e-17
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 3.1559e-09
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 5.0668e-09
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 6.0456e-09
# ----------------------------------------------------------------------------
# c'x = 0.0275, -b'y = 0.0275
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 3.09e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.64e+19  1.37e+19  1.00e+00 -3.47e+19  6.79e+18  3.75e+19  1.68e-05
#    100| 2.08e-10  8.11e-10  2.87e-10  3.48e-02  3.48e-02  7.49e-17  6.10e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 6.11e-04s
# 	Lin-sys: avg # CG iterations: 2.90, avg solve time: 8.06e-07s
# 	Cones: avg projection time: 6.81e-08s
# ...
# Status: Solved
# Timing: Solve time: 2.16e-04s
# 	Lin-sys: avg # CG iterations: 3.00, avg solve time: 7.59e-07s
# 	Cones: avg projection time: 7.60e-08s
# 	Acceleration: avg step time: 3.28e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.4368e-16, dist(y, K*) = 1.1102e-16, s'y/|s||y| = -6.6067e-17
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 5.8303e-08
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.3386e-07
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 9.9665e-08
# ----------------------------------------------------------------------------
# c'x = 0.0435, -b'y = 0.0435
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 3.11e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.64e+19  1.37e+19  1.00e+00 -3.48e+19  6.85e+18  3.75e+19  1.69e-05
#     40| 5.27e-08  8.97e-08  1.30e-08  5.37e-02  5.37e-02  8.22e-17  2.45e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.46e-04s
# 	Lin-sys: avg # CG iterations: 2.66, avg solve time: 7.14e-07s
# 	Cones: avg projection time: 7.52e-08s
# 	Acceleration: avg step time: 3.94e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 3.4870e-16, dist(y, K*) = 0.0000e+00, s'y/|s||y| = 8.9017e-17
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 5.2720e-08
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 8.9660e-08
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.2985e-08
# ----------------------------------------------------------------------------
# c'x = 0.0537, -b'y = 0.0537
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 3.38e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.65e+19  1.37e+19  1.00e+00 -3.49e+19  6.88e+18  3.75e+19  1.71e-05
#     60| 6.91e-08  1.23e-07  1.95e-07  6.53e-02  6.53e-02  2.58e-17  2.92e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.93e-04s
# 	Lin-sys: avg # CG iterations: 3.21, avg solve time: 7.55e-07s
# 	Cones: avg projection time: 7.60e-08s
# 	Acceleration: avg step time: 3.16e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.7717e-16, dist(y, K*) = 0.0000e+00, s'y/|s||y| = 4.7698e-17
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 6.9101e-08
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.2299e-07
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.9453e-07
# ----------------------------------------------------------------------------
# c'x = 0.0653, -b'y = 0.0653
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 3.31e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.65e+19  1.37e+19  1.00e+00 -3.49e+19  6.91e+18  3.75e+19  1.72e-05
#     40| 1.21e-08  2.35e-08  4.54e-09  7.84e-02  7.84e-02  4.22e-17  2.02e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.03e-04s
# 	Lin-sys: avg # CG iterations: 2.37, avg solve time: 6.67e-07s
# 	Cones: avg projection time: 7.13e-08s
# 	Acceleration: avg step time: 3.25e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 4.5891e-17, dist(y, K*) = 1.1102e-16, s'y/|s||y| = 1.4755e-16
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.2080e-08
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 2.3506e-08
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 4.5427e-09
# ----------------------------------------------------------------------------
# c'x = 0.0784, -b'y = 0.0784
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 2.82e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.65e+19  1.37e+19  1.00e+00 -3.50e+19  6.94e+18  3.76e+19  1.67e-05
#     40| 3.06e-09  6.39e-09  9.06e-09  9.29e-02  9.29e-02  5.04e-17  2.09e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.10e-04s
# 	Lin-sys: avg # CG iterations: 2.44, avg solve time: 6.97e-07s
# 	Cones: avg projection time: 7.16e-08s
# 	Acceleration: avg step time: 3.34e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 5.2845e-16, dist(y, K*) = 0.0000e+00, s'y/|s||y| = 2.9508e-17
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 3.0584e-09
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 6.3886e-09
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 9.0636e-09
# ----------------------------------------------------------------------------
# c'x = 0.0929, -b'y = 0.0929
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 2.99e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.65e+19  1.37e+19  1.00e+00 -3.50e+19  6.97e+18  3.76e+19  1.67e-05
#     40| 4.49e-08  4.64e-08  7.79e-08  1.09e-01  1.09e-01  1.38e-16  2.42e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.43e-04s
# 	Lin-sys: avg # CG iterations: 2.59, avg solve time: 7.72e-07s
# 	Cones: avg projection time: 7.45e-08s
# 	Acceleration: avg step time: 4.05e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 5.8419e-16, dist(y, K*) = 0.0000e+00, s'y/|s||y| = 4.0070e-17
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 4.4854e-08
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 4.6396e-08
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 7.7900e-08
# ----------------------------------------------------------------------------
# c'x = 0.1089, -b'y = 0.1089
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 3.33e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.65e+19  1.37e+19  1.00e+00 -3.51e+19  7.00e+18  3.76e+19  1.71e-05
#     40| 2.36e-08  7.29e-08  6.43e-08  1.26e-01  1.26e-01  3.43e-17  2.02e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.03e-04s
# 	Lin-sys: avg # CG iterations: 2.56, avg solve time: 7.07e-07s
# 	Cones: avg projection time: 7.15e-08s
# 	Acceleration: avg step time: 3.20e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.8143e-16, dist(y, K*) = 1.1102e-16, s'y/|s||y| = 1.8958e-16
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 2.3564e-08
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 7.2851e-08
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 6.4252e-08
# ----------------------------------------------------------------------------
# c'x = 0.1263, -b'y = 0.1263
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 2.90e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.65e+19  1.37e+19  1.00e+00 -3.51e+19  7.04e+18  3.76e+19  1.68e-05
#     40| 2.18e-06  4.52e-06  2.21e-06  1.45e-01  1.45e-01  2.54e-17  2.04e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.05e-04s
# 	Lin-sys: avg # CG iterations: 3.61, avg solve time: 8.51e-07s
# 	Cones: avg projection time: 7.61e-08s
# 	Acceleration: avg step time: 3.12e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 2.0142e-16, dist(y, K*) = 0.0000e+00, s'y/|s||y| = 2.2209e-16
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 2.1816e-06
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 4.5200e-06
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 2.2109e-06
# ----------------------------------------------------------------------------
# c'x = 0.1452, -b'y = 0.1452
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 2.64e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.65e+19  1.38e+19  1.00e+00 -3.52e+19  7.07e+18  3.76e+19  1.65e-05
#     40| 3.08e-06  6.32e-06  2.33e-06  1.66e-01  1.66e-01  5.96e-17  2.08e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.09e-04s
# 	Lin-sys: avg # CG iterations: 3.66, avg solve time: 8.46e-07s
# 	Cones: avg projection time: 7.46e-08s
# 	Acceleration: avg step time: 3.23e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 5.7149e-16, dist(y, K*) = 1.1102e-16, s'y/|s||y| = -2.2812e-16
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 3.0752e-06
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 6.3248e-06
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 2.3320e-06
# ----------------------------------------------------------------------------
# c'x = 0.1656, -b'y = 0.1656
# ============================================================================
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-indirect, nnz in A = 34, CG tol ~ 1/iter^(2.00)
# eps = 1.00e-05, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 7, constraints m = 16
# Cones:	primal zero / dual free vars: 2
# 	linear vars: 6
# 	soc vars: 8, soc blks: 2
# Setup time: 2.64e-05s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.65e+19  1.38e+19  1.00e+00 -3.52e+19  7.10e+18  3.76e+19  1.66e-05
#     40| 1.01e-06  1.91e-06  2.81e-06  1.87e-01  1.87e-01  5.78e-17  2.03e-04
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.04e-04s
# 	Lin-sys: avg # CG iterations: 3.49, avg solve time: 8.27e-07s
# 	Cones: avg projection time: 7.70e-08s
# 	Acceleration: avg step time: 3.13e-06s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 9.9502e-16, dist(y, K*) = 0.0000e+00, s'y/|s||y| = -4.8725e-17
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.007

# %%
print(risk)
# Out:
# [0.012814819705709355, 0.012814819505297718, 0.012814819649456641, 0.012814819628001524, 0.012814819457429105, 0.012814819699818637, 0.012814819611565224, 0.012814819504540028, 0.012814819619507596, 0.012812840948855342, 0.012814242702273857, 0.012821797739485928, 0.012825387383905451, 0.012814819630150626, 0.01281840782979997, 0.012814818670986841, 0.012814821716946692, 0.012814819692823106, 0.012814819601003957, 0.012814818715378144, 0.012814801705538436, 0.012814819563655922, 0.012987273370575082, 0.014435774756197943, 0.017334860159015388, 0.021690634454853173, 0.02749738481613825, 0.03476081150863317, 0.043478968599441725, 0.05365201557544136, 0.06527993079323356, 0.07836234832434708, 0.09289966779450369, 0.10889170965934368, 0.12633863822646754, 0.14524070150600552, 0.16559427508633634, 0.1874124102215282, 0.21095998512129555, 0.23700302603651588, 0.26557750415601394, 0.29668325578195454, 0.33032004728030645, 0.3664880822882877, 0.4051871843749961, 0.4464177579999753, 0.49017937009017987, 0.5364720122606373, 0.5852961865473315, 0.6366513796660908]

# %%
plot(rs, risk)

# %%
# Minimizing variance given minimum r value

function min_var(x̄, Σ, r)
    model = Model(Ipopt.Optimizer)
    set_optimizer_attribute(model, "max_cpu_time", 6000.0)
    set_optimizer_attribute(model, "print_level", 0)


    @variable(model, p[1:4])
    @variable(model, t)

    @objective(model, Min, p'*Σ*p)


    @constraint(model, sum(p) == 1)
    @constraint(model, p .>= 0)
    @constraint(model, x̄'*p >= r)


#     print(model)
    
    optimize!(model)
#     println("Termination status : ", termination_status(model))
#     println("Primal status      : ", primal_status(model))
    
    obj_value = objective_value(model)
    p = value.(p)
    println("Risk value for reward = $r: ",obj_value)
#     print("Portfolio composition: ",p)
    
    return obj_value
end
# Out:
# min_var (generic function with 1 method)

# %%
min_var(x̄, Σ, .1)
# Out:
# Risk value for reward = 0.1: 0.012814819608478446
# 0.012814819608478446

# %%
# Out:
# Risk value for reward = 1.04: 0.012814819608490416
# Risk value for reward = 1.08: 0.012814819608478543
# Risk value for reward = 1.12: 0.014435773073482212
# Risk value for reward = 1.16: 0.07836231232006344
# Risk value for reward = 1.2: 0.23700299853839102
# Risk value for reward = 1.24: 0.5364720555183524
# Risk value for reward = 1.28: 0.6681551472483358
# Risk value for reward = 1.32: 0.8428128535485717
# Risk value for reward = 1.36: 0.7536539692368286
# Risk value for reward = 1.4: 0.8117769148259519
# Risk value for reward = 1.44: 0.8504860758153575
# Risk value for reward = 1.48: 1.0320932779610006
# Risk value for reward = 1.52: 1.1090644081617294
# Risk value for reward = 1.56: 1.1747276946813465
# Risk value for reward = 1.6: 1.2435963190607406
# Risk value for reward = 1.64: 1.2697304357005592
# Risk value for reward = 1.68: 1.3339342462192465
# Risk value for reward = 1.72: 1.3999961997729717
# Risk value for reward = 1.76: 1.2621505296692934
# Risk value for reward = 1.8: 1.5375291569441099
# Risk value for reward = 1.84: 1.6089072415362302
# Risk value for reward = 1.88: 1.6808221717919032
# Risk value for reward = 1.92: 1.7554949099536143
# Risk value for reward = 1.96: 1.831761963711142
# Risk value for reward = 2.0: 1.9095871408721978
# Risk value for reward = 2.04: 1.9889349927788138
# Risk value for reward = 2.08: 2.069769773679352
# Risk value for reward = 2.12: 2.152054446798293
# Risk value for reward = 2.16: 2.258374475453823
# Risk value for reward = 2.2: 2.347565498180668
# Risk value for reward = 2.24: 2.429917195473043
# Risk value for reward = 2.28: 2.5049057356724016
# Risk value for reward = 2.32: 2.5813495901273034
# Risk value for reward = 2.36: 2.658657120498586
# Risk value for reward = 2.4: 2.737253868498818
# Risk value for reward = 2.44: 2.8324868634023175
# Risk value for reward = 2.48: 2.9174511742863403
# Risk value for reward = 2.52: 3.0045071031657233
# Risk value for reward = 2.56: 3.093745301586155
# Risk value for reward = 2.6: 3.1852106043790895
# Risk value for reward = 2.64: 3.2789174598945943
# Risk value for reward = 2.68: 3.374862609009629
# Risk value for reward = 2.72: 3.4730589901500566
# Risk value for reward = 2.76: 4.700952811604079
# Risk value for reward = 2.8: 3.573963219413469
# Risk value for reward = 2.84: 3.5683679272092577
# Risk value for reward = 2.88: 3.6359650345108605
# Risk value for reward = 2.92: 3.516615896360943
# Risk value for reward = 2.96: 3.611450940189208
# Risk value for reward = 3.0: 3.710532955204744

# %%
plot(rs, risk)

# %%
rs[2]
# Out:
# 1.08
